# %% [markdown]
# ![Top](./images/watsonxdata.png "watsonxdata")

# %% [markdown]
# # Watsonx.data Sample Notebooks
# These series of notebooks will demonstrate how to connect to the various databases and services that are running on the watsonx server.

# %% [markdown]
# ## Introduction and Utilities
# The following notebooks provide reference information for accessing watsonx.data.

# %% [markdown]
# <!-- Row 0 -->
# <div style="font-family: 'IBM Plex Sans';">
# <table style="float:left; width: 620px; height: 235px; border-spacing: 10px; border-collapse: separate; table-layout: fixed">
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height: 250px;">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# Introduction to Jupyter Notebooks
#         </div>
#         <div style="height: 125px"><p style="font-size: 14px">
# <!-- Description -->
# If you are not familiar with Jupyter notebooks, select this document to learn about the basics of navigating within a notebook.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
# <!-- Duration -->
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
# <!-- URL -->
# <a href="./An_Introduction_to_Jupyter_Notebooks.ipynb">
#         <img style="display: inline-block;"src="images/arrowblue.png"></a>
#         </div>
#     </td>
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height:250px">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# Watsonx.data Credentials
# </div>
#         <div style="height: 125px"><p style="font-size: 14px">
# <!-- Abstract -->
# All the credentials required to connect to the watsonx.data services can be found in this notebook. The notebook also includes links for download the Presto certificate files.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
# <!-- URL -->
# <a href="./Credentials.ipynb">
#                  <img style="display: inline-block;"src="images/arrowblue.png"></a>
#         </div>
#     </td>
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height: 250px;">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# User Administration
#         </div>
#         <div style="height: 125px"><p style="font-size: 14px">
# <!-- Description -->
# The watsonx.data developer edition does not provide a way of adding new users through the UI. The following notebook provides a series of commands that allows for the creation and deletion of users in the system.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
# <!-- Duration -->
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
# <!-- URL -->
# <a href="./Administration.ipynb">
#         <img style="display: inline-block;"src="images/arrowblue.png"></a>
#         </div>
#     </td>
# </table>
# </div>

# %% [markdown]
# ## Watsonx.data and Presto SQL
# The notebooks below explore the SQL that is available in Presto and introduce the user to Presto Magic commands which simplify the connection and execution of SQL statements.

# %% [markdown]
# <div style="font-family: 'IBM Plex Sans';">
# <table style="float:left; width: 620px; height: 235px; border-spacing: 10px; border-collapse: separate; table-layout: fixed">
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height:250px">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# Presto Magic Commands
# </div>
#         <div style="height: 125px"><p style="font-size: 14px">
# <!-- Abstract -->
# Presto Magic commands make it easy to run SQL in cells in your Jupyter Notebook as is, without any Python code. This notebook shows how to enable this feature for watsonx.data and provides some examples of its use.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
# <!-- URL -->
# <a href="./Presto Magic.ipynb">
#                  <img style="display: inline-block;"src="images/arrowblue.png"></a>
#         </div>
#     </td>
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height:250px">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# Introduction to Presto SQL
# </div>
#         <div style="height: 125px"><p style="font-size: 14px">
# <!-- Abstract -->
# Watsonx.data is based on open source PrestoDB, a distributed query engine that enables querying data stored in open file formats using open table formats for optimization or performance.  This notebook will examine some of the SQL features that are available in watsonx.data.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
# <!-- URL -->
# <a href="./Presto SQL.ipynb">
#                  <img style="display: inline-block;"src="images/arrowblue.png"></a>
#         </div>
#     </td>
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height: 250px;">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# Presto Federation
#         </div>
#         <div style="height: 125px"><p style="font-size: 14px">
# <!-- Description -->
# If you are not familiar with Jupyter notebooks, select this document to learn about the basics of navigating within a notebook.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
# <!-- Duration -->
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
# <!-- URL -->
# <a href="./Presto Federation.ipynb">
#         <img style="display: inline-block;"src="images/arrowblue.png"></a>
#         </div>
#     </td>
# </table>
# </div>

# %% [markdown]
# ## Accessing watsonx.data with Python, Pandas, and Apache Spark
# There are a variety of ways that you can access the data within watsonx.data. These notebooks demonstrate how you can use Python, Pandas Dataframes, and Spark to access the Presto database.

# %% [markdown]
# <div style="font-family: 'IBM Plex Sans';">
# <table style="float:left; width: 620px; height: 235px; border-spacing: 10px; border-collapse: separate; table-layout: fixed">
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height: 250px;">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# Python with watsonx.data
#         </div>
#         <div style="height: 125px"><p style="font-size: 14px">
# <!-- Description -->
# This notebook will connect to watsonx.data using Python code and the prestodb library. The DBAPI interface is used to communicate to the watsonx.data Presto server.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
# <!-- Duration -->
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
# <!-- URL -->
# <a href="./Python Example.ipynb">
#         <img style="display: inline-block;"src="images/arrowblue.png"></a>
#         </div>
#     </td>
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height:250px">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# Pandas Dataframes with watsonx.data
# </div>
#         <div style="height: 125px"><p style="font-size: 14px">
# <!-- Abstract -->
# Pandas dataframes are commonly used in Jupyter notebooks to analyze data. This code will connect to watsonx.data using a Pandas dataframe and display some data from an existing table that was created in Presto.
# Note that the certificate required for this notebook is provided in the environment.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
# <!-- URL -->
# <a href="./Pandas Example.ipynb">
#                  <img style="display: inline-block;"src="images/arrowblue.png"></a>
#         </div>
#     </td>
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height:250px">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# Accessing watsonx.data with Spark
# </div>
#         <div style="height: 125px"><p style="font-size: 14px">
# <!-- Abstract -->
# This notebook demonstrates how Spark can connect to watsonx.data and manipulate the data. This system has a local Spark engine that will be used to access watsonx.data. This is a minimally configured Spark engine, but is sufficient to demonstrate the steps needed to connect to watsonx.data and access the data that resides in the catalogs.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
# <!-- URL -->
# <a href="./Spark and watsonxdata Integration.ipynb">
#                  <img style="display: inline-block;"src="images/arrowblue.png"></a>
#         </div>
#     </td>
# </table>
# </div>

# %% [markdown]
# <div style="font-family: 'IBM Plex Sans';">
# <table style="float:left; width: 300px; height: 235px; border-spacing: 10px; border-collapse: separate; table-layout: fixed">
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height: 250px;">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# Converting CSV files to Parquet
#         </div>
#         <div style="height: 125px"><p style="font-size: 14px">
# <!-- Description -->
# This notebook demonstrates how to convert a CSV file into Parquet format.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
# <!-- Duration -->
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
# <!-- URL -->
# <a href="./Convert CSV to Parquet.ipynb">
#         <img style="display: inline-block;"src="images/arrowblue.png"></a>
#         </div>
#     </td>
# </table>
# </div>

# %% [markdown]
# ## Accessing watsonx.data Databases and Services
# Three databases (Db2, PostgreSQL, and MySQL) are included within the watsonx.data developer server. These notebooks provide examples of code to access these databases natively inside the watsonx.data server.

# %% [markdown]
# <div style="font-family: 'IBM Plex Sans';">
# <table style="float:left; width: 620px; height: 235px; border-spacing: 10px; border-collapse: separate; table-layout: fixed">
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height: 250px;">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# Connecting to Db2
#         </div>
#         <div style="height: 125px"><p style="font-size: 14px">
# <!-- Description -->
# This notebook demonstrates connecting to the local Db2 server using Jupyter notebooks.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
# <!-- Duration -->
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
# <!-- URL -->
# <a href="./Db2 Example.ipynb">
#         <img style="display: inline-block;"src="images/arrowblue.png"></a>
#         </div>
#     </td>
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height:250px">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# Connecting to PostgreSQL
# </div>
#         <div style="height: 125px"><p style="font-size: 14px">
# <!-- Abstract -->
# This notebook demonstrates connecting to the local PostgreSQL server using Jupyter notebooks.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
# <!-- URL -->
# <a href="./PostgreSQL Example.ipynb">
#                  <img style="display: inline-block;"src="images/arrowblue.png"></a>
#         </div>
#     </td>
#    <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height: 250px;">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# Connecting to MySQL
#         </div>
#         <div style="height: 125px"><p style="font-size: 14px">
# <!-- Abstract -->
# This notebook demonstrates connecting to the local MySQL server using Jupyter notebooks.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
# <!-- URL -->
# <a href="./MySQL Example.ipynb">
#                  <img style="display: inline-block;"src="images/arrowblue.png"></a>
#         </div>
#     </td>
# </table>
# </div>

# %% [markdown]
# ## Milvus Vector Database
# Milvus is a vector database that stores, indexes and queries across embedding vectors which are generated from unstructured data (images, text etc.) using deep learning models. Milvus is currently in technical preview as part of watsonx.data, but is included in this image for users to become familiar with the technology.

# %% [markdown]
# <div style="font-family: 'IBM Plex Sans';">
# <table style="float:left; width: 300px; height: 235px; border-spacing: 10px; border-collapse: separate; table-layout: fixed">
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height: 250px;">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# Connecting to Milvus
#         </div>
#         <div style="height: 125px"><p style="font-size: 14px">
# <!-- Description -->
# This notebook demonstrates connecting to the local Milvus vector database server using a Jupyter notebook.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
# <!-- Duration -->
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
# <!-- URL -->
# <a href="./Milvus Example.ipynb">
#         <img style="display: inline-block;"src="images/arrowblue.png"></a>
#         </div>
#     </td>
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height: 250px;">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# Milvus Example
#         </div>
#         <div style="height: 125px"><p style="font-size: 14px">
# <!-- Description -->
# Watsonx is IBM's platform committed to injecting generative AI into services that span across customer's data lifecycle. This notebook focusses on the use of watsonx.data as a data repository that is used to feed data into the Milvus vector database. Output from a Milvus query can then be used to generate a prompt into watsonx.ai.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
# <!-- Duration -->
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
# <!-- URL -->
# <a href="./Milvus Example Usage.ipynb">
#         <img style="display: inline-block;"src="images/arrowblue.png"></a>
#         </div>
#     </td>
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height: 250px;">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# Milvus Attu Console
#         </div>
#         <div style="height: 125px"><p style="font-size: 14px">
# <!-- Description -->
# The Milvus vector database does not ship with a console in watsonx.data. If you want to use the supported console you will need to use this notebook to start up the Attu console.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
# <!-- Duration -->
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
# <!-- URL -->
# <a href="./Milvus Console.ipynb">
#         <img style="display: inline-block;"src="images/arrowblue.png"></a>
#         </div>
#     </td>
# </table>
# </div>

# %% [markdown]
# <div style="font-family: 'IBM Plex Sans';">
# <table style="float:left; width: 300px; height: 235px; border-spacing: 10px; border-collapse: separate; table-layout: fixed">
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height: 250px;">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# Open WebUI and Ollama
#         </div>
#         <div style="height: 125px"><p style="font-size: 14px">
# <!-- Description -->
# Ollama is an open-source project that serves as a platform for running LLMs (i.e., IBM Instructlab, Llama 3, Mistral, Gemma 2) on a local machine. Ollama is accessed via Open WebUI, which is an extensible, self-hosted interface for AI. This notebook installs these services in your environment to demonstrate prompt usage.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
# <!-- Duration -->
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
# <!-- URL -->
# <a href="./Ollama.ipynb">
#         <img style="display: inline-block;"src="images/arrowblue.png"></a>
#         </div>
#     </td>
# </table>
# </div>

# %% [markdown]
# ## Kafka
# Apache Kafka is an open-source distributed event streaming platform. It processes streams of events with joins, aggregations, filters, transformations, and more, using event-time and exactly-once processing. The notebooks below are used to create a Kafka service and demonstrate the connectivity with watsonx.data.

# %% [markdown]
# <div style="font-family: 'IBM Plex Sans';">
# <table style="float:left; width: 300px; height: 235px; border-spacing: 10px; border-collapse: separate; table-layout: fixed">
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height: 250px;">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# Create a Kafka Service
#         </div>
#         <div style="height: 125px"><p style="font-size: 14px">
# <!-- Description -->
# This notebook demonstrates how to create a Kafka service, create and send messages to a Topic, and access the Kafka data within watsonx.data.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
# <!-- Duration -->
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
# <!-- URL -->
# <a href="./Kafka.ipynb">
#         <img style="display: inline-block;"src="images/arrowblue.png"></a>
#         </div>
#     </td>
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height: 250px;">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# Kafka Console
#         </div>
#         <div style="height: 125px"><p style="font-size: 14px">
# <!-- Description -->
# UI for Apache Kafka is a free, open-source web UI to monitor and manage Apache Kafka clusters. It is a lightweight dashboard that makes it easy track key metrics of your Kafka clusters, including Brokers, Topics, Partitions, Production, and Consumption.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
# <!-- Duration -->
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
# <!-- URL -->
# <a href="./Kafka Console.ipynb">
#         <img style="display: inline-block;"src="images/arrowblue.png"></a>
#         </div>
#     </td>
# </table>
# </div>

# %% [markdown]
# ## RESTful Support
# Representational state transfer (REST) is a software architectural style that defines a set of constraints to be used for creating Web services. Web services that conform to the REST architectural style, called RESTful Web services, provide interoperability between computer systems on the internet. Presto provides provides RESTful services which are explored in the following notebook.

# %% [markdown]
# <div style="font-family: 'IBM Plex Sans';">
# <table style="float:left; width: 300px; height: 235px; border-spacing: 10px; border-collapse: separate; table-layout: fixed">
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height: 250px;">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# Using RESTful Services in Presto
#         </div>
#         <div style="height: 125px"><p style="font-size: 14px">
# <!-- Description -->
# Presto provides System and Query RESTful APIs. This notebook will use two RESTful calls that check the status of the server and run a query to retrieve a result set.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
# <!-- Duration -->
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
# <!-- URL -->
# <a href="./Restful.ipynb">
#         <img style="display: inline-block;"src="images/arrowblue.png"></a>
#         </div>
#     </td>
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height: 250px;">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# Using RESTful Services in watsonx.data
#         </div>
#         <div style="height: 125px"><p style="font-size: 14px">
# <!-- Description -->
# Watsonx.data provides additional RESTful APIs that provide access to underlying engines, buckets, catalogs, schemas, tables and services. This notebook will explore a numer of the RESTful calls, including an example of querying tables through watsonx.data rather than the Presto RESTful API.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
# <!-- Duration -->
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
# <!-- URL -->
# <a href="./Restful-watsonx.ipynb">
#         <img style="display: inline-block;"src="images/arrowblue.png"></a>
#         </div>
#     </td>
# </table>
# </div>

# %% [markdown]
# ## External Notebook Access
# Instructions on how to use these notebooks outside of the watsonx.data server are found below. In addition, these notebooks are being constantly being updated. To refresh these notebooks, please refer to the document below on updating the Table of Contents.

# %% [markdown]
# <!-- Row 0 -->
# <div style="font-family: 'IBM Plex Sans';">
# <table style="float:left; width: 620px; height: 235px; border-spacing: 10px; border-collapse: separate; table-layout: fixed">
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height: 250px;">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# Running Notebooks in an External Server
#         </div>
#         <div style="height: 125px"><p style="font-size: 14px">
# <!-- Description -->
# The Jupyter notebooks found in the watsonx.data server can be hosted on an external server. This notebook will provide details of what code needs to be installed to run the examples in another server.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
# <!-- Duration -->
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
# <!-- URL -->
# <a href="./External_Jupyter.ipynb">
#         <img style="display: inline-block;"src="images/arrowblue.png"></a>
#         </div>
#     </td>
#     <td style="padding: 15px; text-align:left; vertical-align: text-top; background-color:#F7F7F7; width: 300px; height:250px">
#         <div style="height: 75px"><p style="font-size: 24px">
# <!-- Title -->
# New Notebooks
# </div>
#         <div style="height: 125px"><p style="font-size: 14px">
# <!-- Abstract -->
# The notebooks used in the watsonx.data are being updated on a regular basis. This link will show you the notebooks that are available for this system. You can download this notebooks onto your workstation and then use the Jupyter notebook menu to import them into this server.
#         </div>
#         <div style="height: 25px"><p style="font-size: 12px; text-align: right">
#         </div>
#         <div style="height: 10px"><p style="font-size: 12px; text-align: right">
# <!-- URL -->
# <a href="https://ibm.github.io/watsonx-data-notebooks/">
#                  <img style="display: inline-block;"src="images/arrowblue.png"></a>
#         </div>
#     </td>
# </table>
# </div>

# %% [markdown]
# ##### Copyright (c) IBM 2024, George Baklarz [baklarz@ca.ibm.com] Updated: 2024-08-26
